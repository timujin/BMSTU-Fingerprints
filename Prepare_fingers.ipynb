# %%
import shelve

db = shelve.open("mindtct/shelved_pairs_of_fingers/finger_0.shelve")
pairs_of_fingers = []

for filename in ["mindtct/shelved_pairs_of_fingers/finger_{}.shelve".format(x) for x in range(10)]:
    db = shelve.open(filename)
    pairs_of_fingers.append(db['finger'])

# %%
import math

# %%
from FingerIntoBytes import fingerIntoBytes
pairs_of_finger_arrays = []
for finger1, finger2 in pairs_of_fingers:
    finger1 = [x-128 if x != 256 else 127 for x in fingerIntoBytes(finger1)]
    finger2 = [x-128 if x != 256 else 127 for x in fingerIntoBytes(finger2)]
    
    pairs_of_finger_arrays.append((finger1,finger2))
# Out:
# 230 [62, -93, -100, 68, -118, -118, -125, 80, -58, -115, -127, 75, -56, -99, -127, 71, -64, -115, -127, 67, -54, -98, -126, 97, 75, -104, 110, 5, -98, -119, 106, 33, -103, -122, 125, -58, -99, -112, 121, 28, -102, -121, 108, 73, -120, -127, 108, 73, -120, 112, -73, -115, -114, 110, 5, -98, -120, 125, -58, -99, -113, 121, 28, -102, -122, 127, 127, 127, 127, 106, 33, -103, 112, -73, -115, -118, 110, 5, -98, -125, 125, -58, -99, -118, 121, 28, -102, -127, 108, 73, -120, -122, 58, 84, -120, 60, 58, -120, -124, 68, 53, -104, -123, 75, 71, -120, -126, 82, 94, -120, -127, 83, 103, -104, -126, 75, 71, -120, 106, 33, -103, -123, 108, 73, -120, -127, 97, 75, -104, -128, 82, 94, -120, -125, 83, 103, -104, -124, -42, 60, -119, -28, 40, -103, -125, -33, 56, -103, -128, -30, 74, -104, -127, -33, 101, -104, -123, -36, 95, -104, -123, 60, 58, -120, 63, 13, -122, -121, 68, 53, -104, -127, 97, 75, -104, -126, 75, 71, -120, -126, 82, 94, -120, -123, 52, 52, -104, 55, 33, -120, -125, 68, 53, -104, -128, 60, 58, -120, -127, 75, 71, -120, -125, 58, 84, -120, -124, -47, 53, -104, -47, 40, -119, -126, -28, 40, -103, -126, -33, 56, -103, -128, -30, 74, -104, -126, -42, 60, -119, -127]

# %%
for i,pair in enumerate(pairs_of_finger_arrays):
    filename = "mindtct/shelved_pairs_of_bytes/finger_{}.shelve".format(i)
    db = shelve.open(filename)
    db["data"] = pair
    db.close()

# %%
def byte_back_into_finger(bytes):
    def bytes_into_neigh(bytes, shift):
        bytes = bytes[4*shift:4*shift+4]
        return {"mx":bytes[0],"my":bytes[1],"dir":bytes[2],"rc":bytes[3]}
        
    def bytes_into_minutia(bytes):
        bytes = [x+128 for x in bytes]
        return {
            "mx":bytes[0],
            "my":bytes[1],
            "dir":bytes[2],
            "neighbours": [
                bytes_into_neigh(bytes[3:23],i)
                for i in range(5)
            ]
        }
    res = []
    while(bytes):
        minutia, bytes = bytes[:23], bytes[23:]
        res.append(bytes_into_minutia(minutia))
    return res

# %%
test_finger = byte_back_into_finger(pairs_of_finger_arrays[0][0])
test_finger
# Out:
# [{'dir': 28,
#   'mx': 190,
#   'my': 35,
#   'neighbours': [{'dir': 10, 'mx': 196, 'my': 10, 'rc': 3},
#    {'dir': 13, 'mx': 208, 'my': 70, 'rc': 1},
#    {'dir': 29, 'mx': 203, 'my': 72, 'rc': 1},
#    {'dir': 13, 'mx': 199, 'my': 64, 'rc': 1},
#    {'dir': 30, 'mx': 195, 'my': 74, 'rc': 2}]},
#  {'dir': 24,
#   'mx': 225,
#   'my': 203,
#   'neighbours': [{'dir': 30, 'mx': 238, 'my': 133, 'rc': 9},
#    {'dir': 25, 'mx': 234, 'my': 161, 'rc': 6},
#    {'dir': 29, 'mx': 253, 'my': 70, 'rc': 16},
#    {'dir': 26, 'mx': 249, 'my': 156, 'rc': 7},
#    {'dir': 8, 'mx': 236, 'my': 201, 'rc': 1}]},
#  {'dir': 8,
#   'mx': 236,
#   'my': 201,
#   'neighbours': [{'dir': 13, 'mx': 240, 'my': 55, 'rc': 14},
#    {'dir': 30, 'mx': 238, 'my': 133, 'rc': 8},
#    {'dir': 29, 'mx': 253, 'my': 70, 'rc': 15},
#    {'dir': 26, 'mx': 249, 'my': 156, 'rc': 6},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255}]},
#  {'dir': 25,
#   'mx': 234,
#   'my': 161,
#   'neighbours': [{'dir': 13, 'mx': 240, 'my': 55, 'rc': 10},
#    {'dir': 30, 'mx': 238, 'my': 133, 'rc': 3},
#    {'dir': 29, 'mx': 253, 'my': 70, 'rc': 10},
#    {'dir': 26, 'mx': 249, 'my': 156, 'rc': 1},
#    {'dir': 8, 'mx': 236, 'my': 201, 'rc': 6}]},
#  {'dir': 8,
#   'mx': 186,
#   'my': 212,
#   'neighbours': [{'dir': 8, 'mx': 188, 'my': 186, 'rc': 4},
#    {'dir': 24, 'mx': 196, 'my': 181, 'rc': 5},
#    {'dir': 8, 'mx': 203, 'my': 199, 'rc': 2},
#    {'dir': 8, 'mx': 210, 'my': 222, 'rc': 1},
#    {'dir': 24, 'mx': 211, 'my': 231, 'rc': 2}]},
#  {'dir': 8,
#   'mx': 203,
#   'my': 199,
#   'neighbours': [{'dir': 25, 'mx': 234, 'my': 161, 'rc': 5},
#    {'dir': 8, 'mx': 236, 'my': 201, 'rc': 1},
#    {'dir': 24, 'mx': 225, 'my': 203, 'rc': 0},
#    {'dir': 8, 'mx': 210, 'my': 222, 'rc': 3},
#    {'dir': 24, 'mx': 211, 'my': 231, 'rc': 4}]},
#  {'dir': 9,
#   'mx': 86,
#   'my': 188,
#   'neighbours': [{'dir': 25, 'mx': 100, 'my': 168, 'rc': 3},
#    {'dir': 25, 'mx': 95, 'my': 184, 'rc': 0},
#    {'dir': 24, 'mx': 98, 'my': 202, 'rc': 1},
#    {'dir': 24, 'mx': 95, 'my': 229, 'rc': 5},
#    {'dir': 24, 'mx': 92, 'my': 223, 'rc': 5}]},
#  {'dir': 8,
#   'mx': 188,
#   'my': 186,
#   'neighbours': [{'dir': 6, 'mx': 191, 'my': 141, 'rc': 7},
#    {'dir': 24, 'mx': 196, 'my': 181, 'rc': 1},
#    {'dir': 24, 'mx': 225, 'my': 203, 'rc': 2},
#    {'dir': 8, 'mx': 203, 'my': 199, 'rc': 2},
#    {'dir': 8, 'mx': 210, 'my': 222, 'rc': 5}]},
#  {'dir': 24,
#   'mx': 180,
#   'my': 180,
#   'neighbours': [{'dir': 8, 'mx': 183, 'my': 161, 'rc': 3},
#    {'dir': 24, 'mx': 196, 'my': 181, 'rc': 0},
#    {'dir': 8, 'mx': 188, 'my': 186, 'rc': 1},
#    {'dir': 8, 'mx': 203, 'my': 199, 'rc': 3},
#    {'dir': 8, 'mx': 186, 'my': 212, 'rc': 4}]},
#  {'dir': 24,
#   'mx': 81,
#   'my': 181,
#   'neighbours': [{'dir': 9, 'mx': 81, 'my': 168, 'rc': 2},
#    {'dir': 25, 'mx': 100, 'my': 168, 'rc': 2},
#    {'dir': 25, 'mx': 95, 'my': 184, 'rc': 0},
#    {'dir': 24, 'mx': 98, 'my': 202, 'rc': 2},
#    {'dir': 9, 'mx': 86, 'my': 188, 'rc': 1}]}]

# %%
test_finger2 = byte_back_into_finger(pairs_of_finger_arrays[0][1])
test_finger2
# Out:
# [{'dir': 24,
#   'mx': 237,
#   'my': 218,
#   'neighbours': [{'dir': 27, 'mx': 238, 'my': 132, 'rc': 13},
#    {'dir': 9, 'mx': 245, 'my': 20, 'rc': 25},
#    {'dir': 28, 'mx': 247, 'my': 52, 'rc': 21},
#    {'dir': 24, 'mx': 244, 'my': 143, 'rc': 11},
#    {'dir': 23, 'mx': 245, 'my': 188, 'rc': 4}]},
#  {'dir': 23,
#   'mx': 245,
#   'my': 188,
#   'neighbours': [{'dir': 28, 'mx': 247, 'my': 52, 'rc': 15},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255}]},
#  {'dir': 23,
#   'mx': 188,
#   'my': 221,
#   'neighbours': [{'dir': 7, 'mx': 209, 'my': 203, 'rc': 2},
#    {'dir': 23, 'mx': 209, 'my': 231, 'rc': 2},
#    {'dir': 7, 'mx': 228, 'my': 243, 'rc': 5},
#    {'dir': 7, 'mx': 197, 'my': 232, 'rc': 2},
#    {'dir': 8, 'mx': 203, 'my': 242, 'rc': 3}]},
#  {'dir': 8,
#   'mx': 233,
#   'my': 209,
#   'neighbours': [{'dir': 27, 'mx': 238, 'my': 132, 'rc': 11},
#    {'dir': 23, 'mx': 234, 'my': 201, 'rc': 1},
#    {'dir': 24, 'mx': 244, 'my': 143, 'rc': 9},
#    {'dir': 23, 'mx': 245, 'my': 188, 'rc': 2},
#    {'dir': 24, 'mx': 237, 'my': 218, 'rc': 1}]},
#  {'dir': 23,
#   'mx': 155,
#   'my': 227,
#   'neighbours': [{'dir': 23, 'mx': 188, 'my': 221, 'rc': 1},
#    {'dir': 23, 'mx': 209, 'my': 231, 'rc': 3},
#    {'dir': 7, 'mx': 197, 'my': 232, 'rc': 3},
#    {'dir': 8, 'mx': 203, 'my': 242, 'rc': 4},
#    {'dir': 7, 'mx': 173, 'my': 243, 'rc': 3}]},
#  {'dir': 23,
#   'mx': 124,
#   'my': 224,
#   'neighbours': [{'dir': 23, 'mx': 188, 'my': 221, 'rc': 1},
#    {'dir': 23, 'mx': 155, 'my': 227, 'rc': 0},
#    {'dir': 7, 'mx': 197, 'my': 232, 'rc': 4},
#    {'dir': 7, 'mx': 173, 'my': 243, 'rc': 4},
#    {'dir': 8, 'mx': 154, 'my': 243, 'rc': 3}]},
#  {'dir': 24,
#   'mx': 244,
#   'my': 143,
#   'neighbours': [{'dir': 9, 'mx': 245, 'my': 20, 'rc': 14},
#    {'dir': 28, 'mx': 247, 'my': 52, 'rc': 9},
#    {'dir': 23, 'mx': 245, 'my': 188, 'rc': 6},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255},
#    {'dir': 255, 'mx': 255, 'my': 255, 'rc': 255}]},
#  {'dir': 7,
#   'mx': 203,
#   'my': 177,
#   'neighbours': [{'dir': 23, 'mx': 211, 'my': 173, 'rc': 0},
#    {'dir': 23, 'mx': 245, 'my': 188, 'rc': 2},
#    {'dir': 7, 'mx': 226, 'my': 190, 'rc': 2},
#    {'dir': 23, 'mx': 234, 'my': 201, 'rc': 3},
#    {'dir': 7, 'mx': 209, 'my': 203, 'rc': 3}]},
#  {'dir': 8,
#   'mx': 169,
#   'my': 163,
#   'neighbours': [{'dir': 6, 'mx': 197, 'my': 132, 'rc': 4},
#    {'dir': 24, 'mx': 185, 'my': 155, 'rc': 1},
#    {'dir': 7, 'mx': 194, 'my': 152, 'rc': 1},
#    {'dir': 23, 'mx': 211, 'my': 173, 'rc': 2},
#    {'dir': 7, 'mx': 203, 'my': 177, 'rc': 3}]},
#  {'dir': 6,
#   'mx': 59,
#   'my': 198,
#   'neighbours': [{'dir': 6, 'mx': 84, 'my': 169, 'rc': 1},
#    {'dir': 6, 'mx': 74, 'my': 183, 'rc': 0},
#    {'dir': 8, 'mx': 94, 'my': 172, 'rc': 3},
#    {'dir': 23, 'mx': 95, 'my': 185, 'rc': 0},
#    {'dir': 7, 'mx': 87, 'my': 229, 'rc': 5}]}]

# %%
class Matcher:
    NotSimilarAtAll = 10**10
    
    def __init__(self, **params):
        self.N = params["N"]
        self.OptValue = params["OptValue"]
        self.MinDissimilarity = params["MinDissimilarity"]  # MUST be stricter than OptValue
        self.thresholds = params["thresholds"]
        self.weights = params["weights"]
        self.finalMatchThreshold= params["finalMatchThreshold"]
        self.minutiaProcessed = 5
        
    def angle(self, vec1, vec2):
        from math import atan2, pi
        dotproduct = vec1[0]*vec2[0] + vec1[1]*vec2[1]
        determinant= vec1[0]*vec2[1] + vec1[1]*vec2[0]
        return atan2(determinant, dotproduct) + pi
    
    def diff(self, P, N):
        return ((P["mx"]-N["mx"]), (P["my"]-N["my"]))
            
    def rotate(self, vector, steps): # 32 steps in 360 degrees
        x = vector[0]*math.cos(steps*math.pi / 16) - vector[1]*math.sin(steps*math.pi / 16)
        y = vector[0]*math.sin(steps*math.pi / 16) + vector[1]*math.cos(steps*math.pi / 16)
        return (x,y)
       
    def euclidian_distance(self, P,N):
        D  =  self.diff(P,N)
        return (D[0]**2+D[1]**2)**0.5
    
    def distance_relative_angle(self, P,N):
        up = (0,-1)
        Pdir = self.rotate(up,P["dir"])
        D = self.diff(P,N)
        return self.angle((-D[0],-D[1]), Pdir)
    
    def orientation_relative_angle(self, P,N):
        up = (0,-1)
        Pdir = self.rotate(up, P["dir"])
        Ndir = self.rotate(up, N["dir"])
        print (Pdir, Ndir)
        return self.angle(Pdir, Ndir) # maybe inaccurate
        
    def ridge_count(self, P,N):
        return N["rc"]
    
    def bounding_box(self,diffs):
        if not all(
            x < y for (x,y) in zip(diffs, self.thresholds)
        ):
            #print ("Out of the box:", diffs)
            return False
        return (x / y for (x,y) in zip(diffs, self.thresholds))
        
    def match_neighbours(self,p1,p2,n1,n2):
        """print("Parent1: {}\n Neighbour1: {}\n Parent2: {}\n Neighbour2: {}". format(
            str({x:y for (x,y) in p1.items() if x!="neighbours"}),
            str({x:y for (x,y) in n1.items() if x!="neighbours"}),
            str({x:y for (x,y) in p2.items() if x!="neighbours"}),
            str({x:y for (x,y) in n2.items() if x!="neighbours"}),
        ))"""
        Ed1 = self.euclidian_distance(p1,n1)
        Ed2 = self.euclidian_distance(p2,n2)
        Dra1= self.distance_relative_angle(p1,n1)
        Dra2= self.distance_relative_angle(p2,n2)
        Ora1= self.orientation_relative_angle(p1,n1)
        Ora2= self.orientation_relative_angle(p2,n2)
        Rc1 = self.ridge_count(p1,n1)
        Rc2 = self.ridge_count(p2,n2)
        
        print(Ed1,Ed2,Dra1,Dra2,Ora1,Ora2,Rc1,Rc2)
        return False
        
        EdDiff = abs(Ed2-Ed1)
        DraDiff= abs(Dra2-Dra1)
        OraDiff= abs(Ora2-Ora1)
        RcDiff = abs(Rc2 - Rc1)
        
        diffs = (EdDiff, DraDiff, OraDiff, RcDiff)
        
        normalized = self.bounding_box(diffs)
        if not normalized:
            return Matcher.NotSimilarAtAll
        
        weighted_diffs = list(x*y for (x,y) in zip(normalized, self.weights))
        #print("Weighted", weighted_diffs)
        print ("Neighbour match", sum(weighted_diffs))
        return sum(weighted_diffs)
        
    def match_minutia(self,min1, min2):
        #print("1: {} neighs, 2: {} neighs".format(len(min1["neighbours"]),len(min2["neighbours"])))
        matchedIs = []
        matchedJs = []
        totalDissimilarity = 0
        neighboursMatched = 0
        for iindex, I in enumerate(min1["neighbours"]):
            if iindex in matchedIs: continue
            mostSimilarIndex = None
            mostSimilarDissimilarity = None
            for jindex, J in enumerate(min2["neighbours"]):
                if jindex in matchedJs: continue
                dissimilarity = self.match_neighbours(min1,min2,I,J)
                if (dissimilarity is False):
                    continue
                if (mostSimilarDissimilarity is None) or (mostSimilarDissimilarity > dissimilarity):
                    mostSimilarIndex = jindex
                    mostSimilarDissimilarity = dissimilarity
            if mostSimilarDissimilarity is Matcher.NotSimilarAtAll:
                return Matcher.NotSimilarAtAll
            if (mostSimilarIndex is None):
                continue
            matchedIs.append(iindex)
            matchedJs.append(mostSimilarIndex)
            totalDissimilarity += (mostSimilarDissimilarity)
            neighboursMatched += 1
            #print ("Matched {} with {}".format(iindex, mostSimilarIndex))
            if (neighboursMatched >= self.N):
                return totalDissimilarity / neighboursMatched
        return Matcher.NotSimilarAtAll
                
    
    def filter_minutia(self,finger):
        #import itertools
        #return list(itertools.islice(sorted(finger, key=lambda x: -x["rel"]) ,self.minutiaProcessed))
        return finger
    
    def stoppingConditions(self,MatchCost,LastDissimilarity,TotalMatched):
        return any([
            MatchCost / TotalMatched < self.OptValue,
            LastDissimilarity        < self.MinDissimilarity,
        ])
        
    def __call__(self,candidate, reference):
        candidate = self.filter_minutia(candidate)
        reference = self.filter_minutia(reference)
        matchedCs = []
        matchedRs = []
        totalDissimilarity = 0
        minutiaeMatched = 0
        #for cindex, C in enumerate(candidate):
        for cindex, C in [(1,candidate[1])]:
            print ("Matching", cindex)
            if cindex in matchedCs: continue
            mostSimilarIndex = None
            mostSimilarDissimilarity = None
            #for rindex, R in enumerate(reference):
            for rindex, R in [(6,reference[6])]:
                if rindex in matchedRs: continue
                dissimilarity = self.match_minutia(C,R)
                print ("with", rindex, "diss", dissimilarity)
                #print("Returned: {}".format(dissimilarity))
                if (mostSimilarDissimilarity is None) or (mostSimilarDissimilarity > dissimilarity):
                    mostSimilarIndex = rindex
                    mostSimilarDissimilarity = dissimilarity
            #if mostSimilarDissimilarity is Matcher.NotSimilarAtAll:
                #print ("Total mismatch")
            #    return False
            matchedCs.append(cindex)
            matchedRs.append(mostSimilarIndex)
            totalDissimilarity += (mostSimilarDissimilarity)
            minutiaeMatched += 1
            #print("Matched {} with {} at dissimilarity {}".format(cindex,mostSimilarIndex,mostSimilarDissimilarity))
            if self.stoppingConditions(totalDissimilarity, mostSimilarDissimilarity, minutiaeMatched):
                return True
        #print ("Total dissimilarity: {}".format(totalDissimilarity))
        return (totalDissimilarity / minutiaeMatched < self.finalMatchThreshold)

# %%
adam = test = {'MinDissimilarity': 2.2306793596698347,
 'N': 2.0,
 'OptValue': 2.962895941182219,
 'finalMatchThreshold': 9.510819603577431,
 'thresholds': [39.978606828772456,
  13.72104482880197,
  1.03034591789699,
  2],
 'weights': (lambda l: [x/sum(l) for x in l]) ([10,1,1,8])}

# %%
match = Matcher(**test)
match(test_finger, test_finger2)
# Out:
# Matching 1
# (-1.0, 1.8369701987210297e-16) (-0.3826834323650904, -0.9238795325112865)
# (-1.0, 1.8369701987210297e-16) (0.9807852804032304, 0.1950903220161282)
# 71.19691004531025 123.00406497347964 4.89601130655397 4.720518882564634 4.319689898685965 0.19634954084936185 9 14
# (-1.0, 1.8369701987210297e-16) (-0.3826834323650904, -0.9238795325112865)
# (-1.0, 1.8369701987210297e-16) (-0.7071067811865477, -0.7071067811865474)
# 71.19691004531025 91.0494371207203 4.89601130655397 4.745344077998988 4.319689898685965 3.9269908169872414 9 9
# (-1.0, 1.8369701987210297e-16) (-0.3826834323650904, -0.9238795325112865)
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032303, 0.19509032201612866)
# 71.19691004531025 45.01110973970759 4.89601130655397 1.5485777614681777 4.319689898685965 2.9452431127404304 9 6
# (-1.0, 1.8369701987210297e-16) (-0.3826834323650904, -0.9238795325112865)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 71.19691004531025 112.53888216967503 4.89601130655397 1.472896019056435 4.319689898685965 4.5160394395353265 9 255
# (-1.0, 1.8369701987210297e-16) (-0.3826834323650904, -0.9238795325112865)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 71.19691004531025 112.53888216967503 4.89601130655397 1.472896019056435 4.319689898685965 4.5160394395353265 9 255
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032304, -0.1950903220161283)
# (-1.0, 1.8369701987210297e-16) (0.9807852804032304, 0.1950903220161282)
# 42.95346318982906 123.00406497347964 4.923482313607437 4.720518882564634 3.337942194439155 0.19634954084936185 6 14
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032304, -0.1950903220161283)
# (-1.0, 1.8369701987210297e-16) (-0.7071067811865477, -0.7071067811865474)
# 42.95346318982906 91.0494371207203 4.923482313607437 4.745344077998988 3.337942194439155 3.9269908169872414 6 9
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032304, -0.1950903220161283)
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032303, 0.19509032201612866)
# 42.95346318982906 45.01110973970759 4.923482313607437 1.5485777614681777 3.337942194439155 2.9452431127404304 6 6
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032304, -0.1950903220161283)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 42.95346318982906 112.53888216967503 4.923482313607437 1.472896019056435 3.337942194439155 4.5160394395353265 6 255
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032304, -0.1950903220161283)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 42.95346318982906 112.53888216967503 4.923482313607437 1.472896019056435 3.337942194439155 4.5160394395353265 6 255
# (-1.0, 1.8369701987210297e-16) (-0.5555702330196022, -0.8314696123025452)
# (-1.0, 1.8369701987210297e-16) (0.9807852804032304, 0.1950903220161282)
# 135.9154148726332 123.00406497347964 4.919885206819893 4.720518882564634 4.123340357836604 0.19634954084936185 16 14
# (-1.0, 1.8369701987210297e-16) (-0.5555702330196022, -0.8314696123025452)
# (-1.0, 1.8369701987210297e-16) (-0.7071067811865477, -0.7071067811865474)
# 135.9154148726332 91.0494371207203 4.919885206819893 4.745344077998988 4.123340357836604 3.9269908169872414 16 9
# (-1.0, 1.8369701987210297e-16) (-0.5555702330196022, -0.8314696123025452)
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032303, 0.19509032201612866)
# 135.9154148726332 45.01110973970759 4.919885206819893 1.5485777614681777 4.123340357836604 2.9452431127404304 16 6
# (-1.0, 1.8369701987210297e-16) (-0.5555702330196022, -0.8314696123025452)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 135.9154148726332 112.53888216967503 4.919885206819893 1.472896019056435 4.123340357836604 4.5160394395353265 16 255
# (-1.0, 1.8369701987210297e-16) (-0.5555702330196022, -0.8314696123025452)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 135.9154148726332 112.53888216967503 4.919885206819893 1.472896019056435 4.123340357836604 4.5160394395353265 16 255
# (-1.0, 1.8369701987210297e-16) (-0.9238795325112866, -0.38268343236509)
# (-1.0, 1.8369701987210297e-16) (0.9807852804032304, 0.1950903220161282)
# 52.773099207835045 123.00406497347964 5.184510962788467 4.720518882564634 3.5342917352885173 0.19634954084936185 7 14
# (-1.0, 1.8369701987210297e-16) (-0.9238795325112866, -0.38268343236509)
# (-1.0, 1.8369701987210297e-16) (-0.7071067811865477, -0.7071067811865474)
# 52.773099207835045 91.0494371207203 5.184510962788467 4.745344077998988 3.5342917352885173 3.9269908169872414 7 9
# (-1.0, 1.8369701987210297e-16) (-0.9238795325112866, -0.38268343236509)
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032303, 0.19509032201612866)
# 52.773099207835045 45.01110973970759 5.184510962788467 1.5485777614681777 3.5342917352885173 2.9452431127404304 7 6
# (-1.0, 1.8369701987210297e-16) (-0.9238795325112866, -0.38268343236509)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 52.773099207835045 112.53888216967503 5.184510962788467 1.472896019056435 3.5342917352885173 4.5160394395353265 7 255
# (-1.0, 1.8369701987210297e-16) (-0.9238795325112866, -0.38268343236509)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 52.773099207835045 112.53888216967503 5.184510962788467 1.472896019056435 3.5342917352885173 4.5160394395353265 7 255
# (-1.0, 1.8369701987210297e-16) (1.0, -6.123233995736766e-17)
# (-1.0, 1.8369701987210297e-16) (0.9807852804032304, 0.1950903220161282)
# 11.180339887498949 123.00406497347964 6.103331807387107 4.720518882564634 6.283185307179586 0.19634954084936185 1 14
# (-1.0, 1.8369701987210297e-16) (1.0, -6.123233995736766e-17)
# (-1.0, 1.8369701987210297e-16) (-0.7071067811865477, -0.7071067811865474)
# 11.180339887498949 91.0494371207203 6.103331807387107 4.745344077998988 6.283185307179586 3.9269908169872414 1 9
# (-1.0, 1.8369701987210297e-16) (1.0, -6.123233995736766e-17)
# (-1.0, 1.8369701987210297e-16) (-0.9807852804032303, 0.19509032201612866)
# 11.180339887498949 45.01110973970759 6.103331807387107 1.5485777614681777 6.283185307179586 2.9452431127404304 1 6
# (-1.0, 1.8369701987210297e-16) (1.0, -6.123233995736766e-17)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 11.180339887498949 112.53888216967503 6.103331807387107 1.472896019056435 6.283185307179586 4.5160394395353265 1 255
# (-1.0, 1.8369701987210297e-16) (1.0, -6.123233995736766e-17)
# (-1.0, 1.8369701987210297e-16) (-0.19509032201612952, -0.9807852804032302)
# 11.180339887498949 112.53888216967503 6.103331807387107 1.472896019056435 6.283185307179586 4.5160394395353265 1 255
# with 6 diss 10000000000
# False

# %%
bytes1 = pairs_of_finger_arrays[0][0]
bytes1
# Out:
# [62,
#  -93,
#  -100,
#  68,
#  -118,
#  -118,
#  -125,
#  80,
#  -58,
#  -115,
#  -127,
#  75,
#  -56,
#  -99,
#  -127,
#  71,
#  -64,
#  -115,
#  -127,
#  67,
#  -54,
#  -98,
#  -126,
#  97,
#  75,
#  -104,
#  110,
#  5,
#  -98,
#  -119,
#  106,
#  33,
#  -103,
#  -122,
#  125,
#  -58,
#  -99,
#  -112,
#  121,
#  28,
#  -102,
#  -121,
#  108,
#  73,
#  -120,
#  -127,
#  108,
#  73,
#  -120,
#  112,
#  -73,
#  -115,
#  -114,
#  110,
#  5,
#  -98,
#  -120,
#  125,
#  -58,
#  -99,
#  -113,
#  121,
#  28,
#  -102,
#  -122,
#  127,
#  127,
#  127,
#  127,
#  106,
#  33,
#  -103,
#  112,
#  -73,
#  -115,
#  -118,
#  110,
#  5,
#  -98,
#  -125,
#  125,
#  -58,
#  -99,
#  -118,
#  121,
#  28,
#  -102,
#  -127,
#  108,
#  73,
#  -120,
#  -122,
#  58,
#  84,
#  -120,
#  60,
#  58,
#  -120,
#  -124,
#  68,
#  53,
#  -104,
#  -123,
#  75,
#  71,
#  -120,
#  -126,
#  82,
#  94,
#  -120,
#  -127,
#  83,
#  103,
#  -104,
#  -126,
#  75,
#  71,
#  -120,
#  106,
#  33,
#  -103,
#  -123,
#  108,
#  73,
#  -120,
#  -127,
#  97,
#  75,
#  -104,
#  -128,
#  82,
#  94,
#  -120,
#  -125,
#  83,
#  103,
#  -104,
#  -124,
#  -42,
#  60,
#  -119,
#  -28,
#  40,
#  -103,
#  -125,
#  -33,
#  56,
#  -103,
#  -128,
#  -30,
#  74,
#  -104,
#  -127,
#  -33,
#  101,
#  -104,
#  -123,
#  -36,
#  95,
#  -104,
#  -123,
#  60,
#  58,
#  -120,
#  63,
#  13,
#  -122,
#  -121,
#  68,
#  53,
#  -104,
#  -127,
#  97,
#  75,
#  -104,
#  -126,
#  75,
#  71,
#  -120,
#  -126,
#  82,
#  94,
#  -120,
#  -123,
#  52,
#  52,
#  -104,
#  55,
#  33,
#  -120,
#  -125,
#  68,
#  53,
#  -104,
#  -128,
#  60,
#  58,
#  -120,
#  -127,
#  75,
#  71,
#  -120,
#  -125,
#  58,
#  84,
#  -120,
#  -124,
#  -47,
#  53,
#  -104,
#  -47,
#  40,
#  -119,
#  -126,
#  -28,
#  40,
#  -103,
#  -126,
#  -33,
#  56,
#  -103,
#  -128,
#  -30,
#  74,
#  -104,
#  -126,
#  -42,
#  60,
#  -119,
#  -127]

# %%
bytes2 = pairs_of_finger_arrays[0][1]
bytes2
# Out:
# [109,
#  90,
#  -104,
#  110,
#  4,
#  -101,
#  -115,
#  117,
#  -108,
#  -119,
#  -103,
#  119,
#  -76,
#  -100,
#  -107,
#  116,
#  15,
#  -104,
#  -117,
#  117,
#  60,
#  -105,
#  -124,
#  117,
#  60,
#  -105,
#  119,
#  -76,
#  -100,
#  -113,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  60,
#  93,
#  -105,
#  81,
#  75,
#  -121,
#  -126,
#  81,
#  103,
#  -105,
#  -126,
#  100,
#  115,
#  -121,
#  -123,
#  69,
#  104,
#  -121,
#  -126,
#  75,
#  114,
#  -120,
#  -125,
#  105,
#  81,
#  -120,
#  110,
#  4,
#  -101,
#  -117,
#  106,
#  73,
#  -105,
#  -127,
#  116,
#  15,
#  -104,
#  -119,
#  117,
#  60,
#  -105,
#  -126,
#  109,
#  90,
#  -104,
#  -127,
#  27,
#  99,
#  -105,
#  60,
#  93,
#  -105,
#  -127,
#  81,
#  103,
#  -105,
#  -125,
#  69,
#  104,
#  -121,
#  -125,
#  75,
#  114,
#  -120,
#  -124,
#  45,
#  115,
#  -121,
#  -125,
#  -4,
#  96,
#  -105,
#  60,
#  93,
#  -105,
#  -127,
#  27,
#  99,
#  -105,
#  -128,
#  69,
#  104,
#  -121,
#  -124,
#  45,
#  115,
#  -121,
#  -124,
#  26,
#  115,
#  -120,
#  -125,
#  116,
#  15,
#  -104,
#  117,
#  -108,
#  -119,
#  -114,
#  119,
#  -76,
#  -100,
#  -119,
#  117,
#  60,
#  -105,
#  -122,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  75,
#  49,
#  -121,
#  83,
#  45,
#  -105,
#  -128,
#  117,
#  60,
#  -105,
#  -126,
#  98,
#  62,
#  -121,
#  -126,
#  106,
#  73,
#  -105,
#  -125,
#  81,
#  75,
#  -121,
#  -125,
#  41,
#  35,
#  -120,
#  69,
#  4,
#  -122,
#  -124,
#  57,
#  27,
#  -104,
#  -127,
#  66,
#  24,
#  -121,
#  -127,
#  83,
#  45,
#  -105,
#  -126,
#  75,
#  49,
#  -121,
#  -125,
#  -69,
#  70,
#  -122,
#  -44,
#  41,
#  -122,
#  -127,
#  -54,
#  55,
#  -122,
#  -128,
#  -34,
#  44,
#  -120,
#  -125,
#  -33,
#  57,
#  -105,
#  -128,
#  -41,
#  101,
#  -121,
#  -123]

# %%
def finger_to_java(x):
    return "new byte[]{{ {} }},".format(','.join([str(y) for y in x]))

# %%
finger_to_java(bytes2)
# Out:
# 'new byte[]{ 109,90,-104,110,4,-101,-115,117,-108,-119,-103,119,-76,-100,-107,116,15,-104,-117,117,60,-105,-124,117,60,-105,119,-76,-100,-113,127,127,127,127,127,127,127,127,127,127,127,127,127,127,127,127,60,93,-105,81,75,-121,-126,81,103,-105,-126,100,115,-121,-123,69,104,-121,-126,75,114,-120,-125,105,81,-120,110,4,-101,-117,106,73,-105,-127,116,15,-104,-119,117,60,-105,-126,109,90,-104,-127,27,99,-105,60,93,-105,-127,81,103,-105,-125,69,104,-121,-125,75,114,-120,-124,45,115,-121,-125,-4,96,-105,60,93,-105,-127,27,99,-105,-128,69,104,-121,-124,45,115,-121,-124,26,115,-120,-125,116,15,-104,117,-108,-119,-114,119,-76,-100,-119,117,60,-105,-122,127,127,127,127,127,127,127,127,75,49,-121,83,45,-105,-128,117,60,-105,-126,98,62,-121,-126,106,73,-105,-125,81,75,-121,-125,41,35,-120,69,4,-122,-124,57,27,-104,-127,66,24,-121,-127,83,45,-105,-126,75,49,-121,-125,-69,70,-122,-44,41,-122,-127,-54,55,-122,-128,-34,44,-120,-125,-33,57,-105,-128,-41,101,-121,-123 },'
