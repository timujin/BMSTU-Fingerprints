# %%
import ParseFingers as PF

# %%
testFinger = PF.parseFilename(r"mindtct/minutie/f0001_01.png.min")
testFinger2 = PF.parseFilename(r"mindtct/minutie/f0002_05.png.min")

# %%
"""
M: 190,35,28; (N: 196, 10, 10, 3; N: 208, 70, 13, 1; N: 203, 72, 29, 1; N: 199, 64, 13, 1; N: 195, 74, 30, 2; );
M: 225,203,24; (N: 238, 133, 30, 9; N: 234, 161, 25, 6; N: 253, 70, 29, 16; N: 249, 156, 26, 7; N: 236, 201, 8, 1; );
M: 236,201,8; (N: 240, 55, 13, 14; N: 238, 133, 30, 8; N: 253, 70, 29, 15; N: 249, 156, 26, 6; N: 255, 255, 255, 255; );
M: 234,161,25; (N: 240, 55, 13, 10; N: 238, 133, 30, 3; N: 253, 70, 29, 10; N: 249, 156, 26, 1; N: 236, 201, 8, 6; );
M: 186,212,8; (N: 188, 186, 8, 4; N: 196, 181, 24, 5; N: 203, 199, 8, 2; N: 210, 222, 8, 1; N: 211, 231, 24, 2; );
M: 203,199,8; (N: 234, 161, 25, 5; N: 236, 201, 8, 1; N: 225, 203, 24, 0; N: 210, 222, 8, 3; N: 211, 231, 24, 4; );
M: 86,188,9; (N: 100, 168, 25, 3; N: 95, 184, 25, 0; N: 98, 202, 24, 1; N: 95, 229, 24, 5; N: 92, 223, 24, 5; );
M: 188,186,8; (N: 191, 141, 6, 7; N: 196, 181, 24, 1; N: 225, 203, 24, 2; N: 203, 199, 8, 2; N: 210, 222, 8, 5; );
M: 180,180,24; (N: 183, 161, 8, 3; N: 196, 181, 24, 0; N: 188, 186, 8, 1; N: 203, 199, 8, 3; N: 186, 212, 8, 4; );
M: 81,181,24; (N: 81, 168, 9, 2; N: 100, 168, 25, 2; N: 95, 184, 25, 0; N: 98, 202, 24, 2; N: 86, 188, 9, 1; );
"""
sorted(testFinger2, key=lambda f: -f["rel"])
# Out:
# [{'dir': 26,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 102,
#   'mx': 316,
#   'my': 357,
#   'neighbours': [{'dir': 27, 'mx': 346, 'my': 299, 'rc': 5},
#    {'dir': 27, 'mx': 389, 'my': 325, 'rc': 5},
#    {'dir': 26, 'mx': 381, 'my': 355, 'rc': 2},
#    {'dir': 26, 'mx': 384, 'my': 382, 'rc': 0},
#    {'dir': 10, 'mx': 378, 'my': 415, 'rc': 4}],
#   'rel': 0.794,
#   'typ': 'RIG'},
#  {'dir': 27,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 115,
#   'mx': 389,
#   'my': 325,
#   'neighbours': [{'dir': 28, 'mx': 442, 'my': 271, 'rc': 6},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 3},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 1},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 8},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 6}],
#   'rel': 0.773,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 100,
#   'mx': 313,
#   'my': 398,
#   'neighbours': [{'dir': 26, 'mx': 316, 'my': 357, 'rc': 3},
#    {'dir': 10, 'mx': 378, 'my': 415, 'rc': 1},
#    {'dir': 25, 'mx': 363, 'my': 445, 'rc': 3},
#    {'dir': 9, 'mx': 340, 'my': 448, 'rc': 4},
#    {'dir': 24, 'mx': 327, 'my': 444, 'rc': 3}],
#   'rel': 0.769,
#   'typ': 'RIG'},
#  {'dir': 29,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 103,
#   'mx': 326,
#   'my': 203,
#   'neighbours': [{'dir': 13, 'mx': 439, 'my': 139, 'rc': 12},
#    {'dir': 29, 'mx': 430, 'my': 153, 'rc': 10},
#    {'dir': 29, 'mx': 381, 'my': 247, 'rc': 1},
#    {'dir': 28, 'mx': 352, 'my': 254, 'rc': 0},
#    {'dir': 27, 'mx': 346, 'my': 299, 'rc': 4}],
#   'rel': 0.757,
#   'typ': 'BIF'},
#  {'dir': 27,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 106,
#   'mx': 346,
#   'my': 299,
#   'neighbours': [{'dir': 28, 'mx': 352, 'my': 254, 'rc': 3},
#    {'dir': 29, 'mx': 381, 'my': 247, 'rc': 5},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 2},
#    {'dir': 27, 'mx': 389, 'my': 325, 'rc': 0},
#    {'dir': 26, 'mx': 381, 'my': 355, 'rc': 3}],
#   'rel': 0.744,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 98,
#   'mx': 304,
#   'my': 211,
#   'neighbours': [{'dir': 29, 'mx': 307, 'my': 192, 'rc': 1},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 2},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 2},
#    {'dir': 29, 'mx': 381, 'my': 247, 'rc': 3},
#    {'dir': 28, 'mx': 352, 'my': 254, 'rc': 0}],
#   'rel': 0.743,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 112,
#   'mx': 381,
#   'my': 355,
#   'neighbours': [{'dir': 27, 'mx': 389, 'my': 325, 'rc': 2},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 3},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 4},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 4},
#    {'dir': 26, 'mx': 384, 'my': 382, 'rc': 1}],
#   'rel': 0.741,
#   'typ': 'BIF'},
#  {'dir': 28,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 96,
#   'mx': 286,
#   'my': 290,
#   'neighbours': [{'dir': 28, 'mx': 304, 'my': 211, 'rc': 5},
#    {'dir': 28, 'mx': 352, 'my': 254, 'rc': 5},
#    {'dir': 27, 'mx': 346, 'my': 299, 'rc': 1},
#    {'dir': 26, 'mx': 316, 'my': 357, 'rc': 3},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 4}],
#   'rel': 0.74,
#   'typ': 'BIF'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 117,
#   'mx': 414,
#   'my': 427,
#   'neighbours': [{'dir': 26, 'mx': 492, 'my': 472, 'rc': 1},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 2},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 2},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 1},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 2}],
#   'rel': 0.738,
#   'typ': 'BIF'},
#  {'dir': 3,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 9,
#   'mx': 70,
#   'my': 56,
#   'neighbours': [{'dir': 4, 'mx': 116, 'my': 27, 'rc': 2},
#    {'dir': 3, 'mx': 132, 'my': 71, 'rc': 5},
#    {'dir': 18, 'mx': 115, 'my': 121, 'rc': 6},
#    {'dir': 2, 'mx': 99, 'my': 123, 'rc': 5},
#    {'dir': 18, 'mx': 80, 'my': 122, 'rc': 3}],
#   'rel': 0.735,
#   'typ': 'RIG'},
#  {'dir': 13,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 87,
#   'mx': 261,
#   'my': 244,
#   'neighbours': [{'dir': 12, 'mx': 264, 'my': 173, 'rc': 4},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 6},
#    {'dir': 28, 'mx': 304, 'my': 211, 'rc': 4},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 6},
#    {'dir': 28, 'mx': 286, 'my': 290, 'rc': 1}],
#   'rel': 0.729,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 107,
#   'mx': 352,
#   'my': 254,
#   'neighbours': [{'dir': 29, 'mx': 381, 'my': 247, 'rc': 2},
#    {'dir': 28, 'mx': 442, 'my': 271, 'rc': 4},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 0},
#    {'dir': 27, 'mx': 389, 'my': 325, 'rc': 3},
#    {'dir': 26, 'mx': 381, 'my': 355, 'rc': 6}],
#   'rel': 0.728,
#   'typ': 'RIG'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 109,
#   'mx': 378,
#   'my': 415,
#   'neighbours': [{'dir': 26, 'mx': 381, 'my': 355, 'rc': 5},
#    {'dir': 26, 'mx': 384, 'my': 382, 'rc': 2},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 0},
#    {'dir': 9, 'mx': 383, 'my': 452, 'rc': 2},
#    {'dir': 25, 'mx': 380, 'my': 463, 'rc': 2}],
#   'rel': 0.727,
#   'typ': 'BIF'},
#  {'dir': 26,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 114,
#   'mx': 384,
#   'my': 382,
#   'neighbours': [{'dir': 27, 'mx': 389, 'my': 325, 'rc': 4},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 5},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 6},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 3},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 6}],
#   'rel': 0.726,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 122,
#   'mx': 442,
#   'my': 271,
#   'neighbours': [{'dir': 28, 'mx': 465, 'my': 110, 'rc': 11},
#    {'dir': 26, 'mx': 492, 'my': 472, 'rc': 11},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 11},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 11},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 2}],
#   'rel': 0.725,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 84,
#   'mx': 255,
#   'my': 287,
#   'neighbours': [{'dir': 13, 'mx': 261, 'my': 244, 'rc': 2},
#    {'dir': 28, 'mx': 286, 'my': 290, 'rc': 1},
#    {'dir': 26, 'mx': 279, 'my': 343, 'rc': 2},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 4},
#    {'dir': 27, 'mx': 255, 'my': 319, 'rc': 2}],
#   'rel': 0.72,
#   'typ': 'BIF'},
#  {'dir': 27,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 118,
#   'mx': 422,
#   'my': 319,
#   'neighbours': [{'dir': 28, 'mx': 442, 'my': 271, 'rc': 4},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 1},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 9},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 9},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 10}],
#   'rel': 0.71,
#   'typ': 'RIG'},
#  {'dir': 29,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 111,
#   'mx': 381,
#   'my': 247,
#   'neighbours': [{'dir': 29, 'mx': 430, 'my': 153, 'rc': 8},
#    {'dir': 28, 'mx': 442, 'my': 271, 'rc': 2},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 0},
#    {'dir': 27, 'mx': 422, 'my': 319, 'rc': 2},
#    {'dir': 27, 'mx': 389, 'my': 325, 'rc': 5}],
#   'rel': 0.709,
#   'typ': 'RIG'},
#  {'dir': 29,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 99,
#   'mx': 307,
#   'my': 192,
#   'neighbours': [{'dir': 13, 'mx': 315, 'my': 183, 'rc': 1},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 1},
#    {'dir': 29, 'mx': 381, 'my': 247, 'rc': 2},
#    {'dir': 28, 'mx': 352, 'my': 254, 'rc': 2},
#    {'dir': 27, 'mx': 346, 'my': 299, 'rc': 4}],
#   'rel': 0.708,
#   'typ': 'RIG'},
#  {'dir': 13,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 101,
#   'mx': 315,
#   'my': 183,
#   'neighbours': [{'dir': 29, 'mx': 430, 'my': 153, 'rc': 10},
#    {'dir': 29, 'mx': 381, 'my': 247, 'rc': 1},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 0},
#    {'dir': 28, 'mx': 352, 'my': 254, 'rc': 1},
#    {'dir': 27, 'mx': 346, 'my': 299, 'rc': 5}],
#   'rel': 0.704,
#   'typ': 'BIF'},
#  {'dir': 28,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 116,
#   'mx': 397,
#   'my': 37,
#   'neighbours': [{'dir': 28, 'mx': 465, 'my': 110, 'rc': 1},
#    {'dir': 13, 'mx': 439, 'my': 139, 'rc': 4},
#    {'dir': 29, 'mx': 430, 'my': 153, 'rc': 5},
#    {'dir': 28, 'mx': 442, 'my': 271, 'rc': 11},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 14}],
#   'rel': 0.702,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 61,
#   'mx': 191,
#   'my': 144,
#   'neighbours': [{'dir': 21, 'mx': 207, 'my': 101, 'rc': 0},
#    {'dir': 3, 'mx': 209, 'my': 140, 'rc': 1},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 3},
#    {'dir': 13, 'mx': 249, 'my': 168, 'rc': 5},
#    {'dir': 15, 'mx': 197, 'my': 211, 'rc': 0}],
#   'rel': 0.695,
#   'typ': 'BIF'},
#  {'dir': 8,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 78,
#   'mx': 229,
#   'my': 24,
#   'neighbours': [{'dir': 25, 'mx': 277, 'my': 36, 'rc': 0},
#    {'dir': 9, 'mx': 243, 'my': 38, 'rc': 1},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 4},
#    {'dir': 25, 'mx': 241, 'my': 46, 'rc': 1},
#    {'dir': 26, 'mx': 262, 'my': 88, 'rc': 6}],
#   'rel': 0.694,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 45,
#   'mx': 158,
#   'my': 148,
#   'neighbours': [{'dir': 3, 'mx': 209, 'my': 140, 'rc': 3},
#    {'dir': 18, 'mx': 191, 'my': 144, 'rc': 2},
#    {'dir': 18, 'mx': 164, 'my': 149, 'rc': 0},
#    {'dir': 0, 'mx': 189, 'my': 179, 'rc': 3},
#    {'dir': 17, 'mx': 183, 'my': 177, 'rc': 3}],
#   'rel': 0.688,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 89,
#   'mx': 263,
#   'my': 117,
#   'neighbours': [{'dir': 25, 'mx': 277, 'my': 36, 'rc': 8},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 4},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 2},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 2},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 5}],
#   'rel': 0.687,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 47,
#   'mx': 164,
#   'my': 149,
#   'neighbours': [{'dir': 21, 'mx': 207, 'my': 101, 'rc': 0},
#    {'dir': 3, 'mx': 209, 'my': 140, 'rc': 4},
#    {'dir': 18, 'mx': 191, 'my': 144, 'rc': 2},
#    {'dir': 0, 'mx': 189, 'my': 179, 'rc': 2},
#    {'dir': 17, 'mx': 183, 'my': 177, 'rc': 2}],
#   'rel': 0.682,
#   'typ': 'BIF'},
#  {'dir': 3,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 71,
#   'mx': 209,
#   'my': 140,
#   'neighbours': [{'dir': 10, 'mx': 261, 'my': 99, 'rc': 3},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 2},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 2},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 5},
#    {'dir': 13, 'mx': 249, 'my': 168, 'rc': 4}],
#   'rel': 0.68,
#   'typ': 'RIG'},
#  {'dir': 29,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 119,
#   'mx': 430,
#   'my': 153,
#   'neighbours': [{'dir': 13, 'mx': 439, 'my': 139, 'rc': 1},
#    {'dir': 28, 'mx': 465, 'my': 110, 'rc': 5},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 16},
#    {'dir': 28, 'mx': 442, 'my': 271, 'rc': 5},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 7}],
#   'rel': 0.668,
#   'typ': 'RIG'},
#  {'dir': 2,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 24,
#   'mx': 111,
#   'my': 238,
#   'neighbours': [{'dir': 16, 'mx': 169, 'my': 221, 'rc': 4},
#    {'dir': 2, 'mx': 170, 'my': 245, 'rc': 5},
#    {'dir': 29, 'mx': 186, 'my': 255, 'rc': 5},
#    {'dir': 4, 'mx': 167, 'my': 290, 'rc': 4},
#    {'dir': 17, 'mx': 121, 'my': 277, 'rc': 1}],
#   'rel': 0.659,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 94,
#   'mx': 277,
#   'my': 36,
#   'neighbours': [{'dir': 28, 'mx': 397, 'my': 37, 'rc': 6},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 11},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 11},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 11},
#    {'dir': 28, 'mx': 304, 'my': 211, 'rc': 13}],
#   'rel': 0.651,
#   'typ': 'BIF'},
#  {'dir': 17,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 56,
#   'mx': 183,
#   'my': 177,
#   'neighbours': [{'dir': 18, 'mx': 191, 'my': 144, 'rc': 0},
#    {'dir': 3, 'mx': 209, 'my': 140, 'rc': 2},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 4},
#    {'dir': 0, 'mx': 189, 'my': 179, 'rc': 0},
#    {'dir': 15, 'mx': 197, 'my': 211, 'rc': 0}],
#   'rel': 0.645,
#   'typ': 'BIF'},
#  {'dir': 13,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 121,
#   'mx': 439,
#   'my': 139,
#   'neighbours': [{'dir': 28, 'mx': 465, 'my': 110, 'rc': 4},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 17},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 17},
#    {'dir': 27, 'mx': 446, 'my': 312, 'rc': 8},
#    {'dir': 28, 'mx': 442, 'my': 271, 'rc': 6}],
#   'rel': 0.644,
#   'typ': 'RIG'},
#  {'dir': 21,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 70,
#   'mx': 207,
#   'my': 101,
#   'neighbours': [{'dir': 26, 'mx': 262, 'my': 88, 'rc': 2},
#    {'dir': 10, 'mx': 261, 'my': 99, 'rc': 2},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 2},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 5},
#    {'dir': 3, 'mx': 209, 'my': 140, 'rc': 2}],
#   'rel': 0.633,
#   'typ': 'RIG'},
#  {'dir': 0,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 58,
#   'mx': 189,
#   'my': 179,
#   'neighbours': [{'dir': 18, 'mx': 191, 'my': 144, 'rc': 0},
#    {'dir': 3, 'mx': 209, 'my': 140, 'rc': 1},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 3},
#    {'dir': 13, 'mx': 249, 'my': 168, 'rc': 5},
#    {'dir': 15, 'mx': 197, 'my': 211, 'rc': 0}],
#   'rel': 0.629,
#   'typ': 'RIG'},
#  {'dir': 10,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 97,
#   'mx': 301,
#   'my': 360,
#   'neighbours': [{'dir': 27, 'mx': 346, 'my': 299, 'rc': 6},
#    {'dir': 26, 'mx': 316, 'my': 357, 'rc': 0},
#    {'dir': 26, 'mx': 381, 'my': 355, 'rc': 2},
#    {'dir': 26, 'mx': 384, 'my': 382, 'rc': 0},
#    {'dir': 25, 'mx': 313, 'my': 398, 'rc': 2}],
#   'rel': 0.402,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 95,
#   'mx': 279,
#   'my': 343,
#   'neighbours': [{'dir': 28, 'mx': 286, 'my': 290, 'rc': 4},
#    {'dir': 27, 'mx': 346, 'my': 299, 'rc': 5},
#    {'dir': 26, 'mx': 316, 'my': 357, 'rc': 0},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 1},
#    {'dir': 25, 'mx': 313, 'my': 398, 'rc': 3}],
#   'rel': 0.391,
#   'typ': 'RIG'},
#  {'dir': 25,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 108,
#   'mx': 363,
#   'my': 445,
#   'neighbours': [{'dir': 26, 'mx': 384, 'my': 382, 'rc': 4},
#    {'dir': 10, 'mx': 378, 'my': 415, 'rc': 2},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 2},
#    {'dir': 9, 'mx': 383, 'my': 452, 'rc': 1},
#    {'dir': 25, 'mx': 380, 'my': 463, 'rc': 0}],
#   'rel': 0.388,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 23,
#   'mx': 108,
#   'my': 159,
#   'neighbours': [{'dir': 18, 'mx': 115, 'my': 121, 'rc': 0},
#    {'dir': 2, 'mx': 158, 'my': 148, 'rc': 4},
#    {'dir': 18, 'mx': 164, 'my': 149, 'rc': 4},
#    {'dir': 18, 'mx': 135, 'my': 159, 'rc': 2},
#    {'dir': 17, 'mx': 183, 'my': 177, 'rc': 8}],
#   'rel': 0.381,
#   'typ': 'RIG'},
#  {'dir': 9,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 83,
#   'mx': 253,
#   'my': 359,
#   'neighbours': [{'dir': 27, 'mx': 255, 'my': 319, 'rc': 4},
#    {'dir': 26, 'mx': 279, 'my': 343, 'rc': 2},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 0},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 0},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 0}],
#   'rel': 0.381,
#   'typ': 'RIG'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 126,
#   'mx': 476,
#   'my': 464,
#   'neighbours': [{'dir': 26, 'mx': 492, 'my': 472, 'rc': 0},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 0}],
#   'rel': 0.38,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 91,
#   'mx': 264,
#   'my': 373,
#   'neighbours': [{'dir': 26, 'mx': 279, 'my': 343, 'rc': 2},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 1},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 1},
#    {'dir': 26, 'mx': 316, 'my': 357, 'rc': 1},
#    {'dir': 25, 'mx': 313, 'my': 398, 'rc': 1}],
#   'rel': 0.379,
#   'typ': 'RIG'},
#  {'dir': 27,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 85,
#   'mx': 255,
#   'my': 319,
#   'neighbours': [{'dir': 28, 'mx': 286, 'my': 290, 'rc': 3},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 1},
#    {'dir': 26, 'mx': 279, 'my': 343, 'rc': 0},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 2},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 4}],
#   'rel': 0.378,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 92,
#   'mx': 274,
#   'my': 356,
#   'neighbours': [{'dir': 28, 'mx': 286, 'my': 290, 'rc': 5},
#    {'dir': 26, 'mx': 279, 'my': 343, 'rc': 1},
#    {'dir': 26, 'mx': 316, 'my': 357, 'rc': 0},
#    {'dir': 10, 'mx': 301, 'my': 360, 'rc': 0},
#    {'dir': 25, 'mx': 313, 'my': 398, 'rc': 2}],
#   'rel': 0.377,
#   'typ': 'RIG'},
#  {'dir': 18,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 12,
#   'mx': 80,
#   'my': 122,
#   'neighbours': [{'dir': 3, 'mx': 132, 'my': 71, 'rc': 2},
#    {'dir': 18, 'mx': 115, 'my': 121, 'rc': 3},
#    {'dir': 2, 'mx': 99, 'my': 123, 'rc': 2},
#    {'dir': 18, 'mx': 135, 'my': 159, 'rc': 6},
#    {'dir': 2, 'mx': 108, 'my': 159, 'rc': 3}],
#   'rel': 0.374,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 77,
#   'mx': 228,
#   'my': 327,
#   'neighbours': [{'dir': 28, 'mx': 255, 'my': 287, 'rc': 4},
#    {'dir': 27, 'mx': 255, 'my': 319, 'rc': 1},
#    {'dir': 26, 'mx': 279, 'my': 343, 'rc': 0},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 1},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 2}],
#   'rel': 0.37,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 25,
#   'mx': 115,
#   'my': 121,
#   'neighbours': [{'dir': 3, 'mx': 132, 'my': 71, 'rc': 1},
#    {'dir': 4, 'mx': 152, 'my': 77, 'rc': 1},
#    {'dir': 18, 'mx': 164, 'my': 149, 'rc': 6},
#    {'dir': 2, 'mx': 158, 'my': 148, 'rc': 5},
#    {'dir': 18, 'mx': 135, 'my': 159, 'rc': 3}],
#   'rel': 0.367,
#   'typ': 'RIG'},
#  {'dir': 12,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 90,
#   'mx': 264,
#   'my': 173,
#   'neighbours': [{'dir': 10, 'mx': 276, 'my': 78, 'rc': 9},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 3},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 2},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 3},
#    {'dir': 28, 'mx': 304, 'my': 211, 'rc': 0}],
#   'rel': 0.367,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 4,
#   'mx': 39,
#   'my': 145,
#   'neighbours': [{'dir': 3, 'mx': 70, 'my': 56, 'rc': 0},
#    {'dir': 18, 'mx': 80, 'my': 122, 'rc': 2},
#    {'dir': 2, 'mx': 99, 'my': 123, 'rc': 5},
#    {'dir': 18, 'mx': 115, 'my': 121, 'rc': 5},
#    {'dir': 2, 'mx': 108, 'my': 159, 'rc': 6}],
#   'rel': 0.362,
#   'typ': 'RIG'},
#  {'dir': 4,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 26,
#   'mx': 116,
#   'my': 27,
#   'neighbours': [{'dir': 23, 'mx': 177, 'my': 15, 'rc': 2},
#    {'dir': 24, 'mx': 221, 'my': 29, 'rc': 5},
#    {'dir': 6, 'mx': 177, 'my': 31, 'rc': 4},
#    {'dir': 4, 'mx': 152, 'my': 77, 'rc': 5},
#    {'dir': 3, 'mx': 132, 'my': 71, 'rc': 3}],
#   'rel': 0.36,
#   'typ': 'BIF'},
#  {'dir': 27,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 123,
#   'mx': 446,
#   'my': 312,
#   'neighbours': [{'dir': 28, 'mx': 465, 'my': 110, 'rc': 13},
#    {'dir': 26, 'mx': 492, 'my': 472, 'rc': 9},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 10},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 9},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 9}],
#   'rel': 0.357,
#   'typ': 'RIG'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 86,
#   'mx': 261,
#   'my': 99,
#   'neighbours': [{'dir': 26, 'mx': 262, 'my': 88, 'rc': 1},
#    {'dir': 25, 'mx': 277, 'my': 36, 'rc': 6},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 2},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 1},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 7}],
#   'rel': 0.353,
#   'typ': 'BIF'},
#  {'dir': 27,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 67,
#   'mx': 204,
#   'my': 298,
#   'neighbours': [{'dir': 28, 'mx': 215, 'my': 273, 'rc': 3},
#    {'dir': 28, 'mx': 255, 'my': 287, 'rc': 4},
#    {'dir': 27, 'mx': 255, 'my': 319, 'rc': 1},
#    {'dir': 26, 'mx': 228, 'my': 327, 'rc': 1},
#    {'dir': 25, 'mx': 206, 'my': 329, 'rc': 3}],
#   'rel': 0.351,
#   'typ': 'RIG'},
#  {'dir': 22,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 79,
#   'mx': 232,
#   'my': 143,
#   'neighbours': [{'dir': 26, 'mx': 262, 'my': 88, 'rc': 5},
#    {'dir': 10, 'mx': 261, 'my': 99, 'rc': 4},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 2},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 2},
#    {'dir': 13, 'mx': 249, 'my': 168, 'rc': 1}],
#   'rel': 0.351,
#   'typ': 'BIF'},
#  {'dir': 6,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 8,
#   'mx': 60,
#   'my': 431,
#   'neighbours': [{'dir': 22, 'mx': 72, 'my': 398, 'rc': 1},
#    {'dir': 20, 'mx': 101, 'my': 381, 'rc': 1},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 2},
#    {'dir': 8, 'mx': 85, 'my': 464, 'rc': 3},
#    {'dir': 7, 'mx': 72, 'my': 463, 'rc': 2}],
#   'rel': 0.348,
#   'typ': 'RIG'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 14,
#   'mx': 94,
#   'my': 351,
#   'neighbours': [{'dir': 18, 'mx': 106, 'my': 316, 'rc': 0},
#    {'dir': 19, 'mx': 104, 'my': 329, 'rc': 0},
#    {'dir': 1, 'mx': 125, 'my': 331, 'rc': 3},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 3},
#    {'dir': 20, 'mx': 101, 'my': 381, 'rc': 0}],
#   'rel': 0.348,
#   'typ': 'BIF'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 88,
#   'mx': 262,
#   'my': 88,
#   'neighbours': [{'dir': 25, 'mx': 277, 'my': 36, 'rc': 5},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 1},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 5},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 3},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 9}],
#   'rel': 0.348,
#   'typ': 'BIF'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 93,
#   'mx': 276,
#   'my': 78,
#   'neighbours': [{'dir': 25, 'mx': 277, 'my': 36, 'rc': 4},
#    {'dir': 28, 'mx': 397, 'my': 37, 'rc': 10},
#    {'dir': 29, 'mx': 326, 'my': 203, 'rc': 6},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 6},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 6}],
#   'rel': 0.343,
#   'typ': 'BIF'},
#  {'dir': 9,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 81,
#   'mx': 243,
#   'my': 38,
#   'neighbours': [{'dir': 25, 'mx': 277, 'my': 36, 'rc': 1},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 3},
#    {'dir': 26, 'mx': 262, 'my': 88, 'rc': 5},
#    {'dir': 10, 'mx': 261, 'my': 99, 'rc': 6},
#    {'dir': 25, 'mx': 263, 'my': 117, 'rc': 7}],
#   'rel': 0.342,
#   'typ': 'RIG'},
#  {'dir': 4,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 44,
#   'mx': 154,
#   'my': 302,
#   'neighbours': [{'dir': 29, 'mx': 186, 'my': 255, 'rc': 2},
#    {'dir': 4, 'mx': 167, 'my': 290, 'rc': 0},
#    {'dir': 27, 'mx': 204, 'my': 298, 'rc': 0},
#    {'dir': 10, 'mx': 189, 'my': 314, 'rc': 2},
#    {'dir': 25, 'mx': 206, 'my': 329, 'rc': 1}],
#   'rel': 0.341,
#   'typ': 'BIF'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 59,
#   'mx': 189,
#   'my': 314,
#   'neighbours': [{'dir': 28, 'mx': 215, 'my': 273, 'rc': 4},
#    {'dir': 27, 'mx': 204, 'my': 298, 'rc': 1},
#    {'dir': 26, 'mx': 228, 'my': 327, 'rc': 0},
#    {'dir': 25, 'mx': 206, 'my': 329, 'rc': 0},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 4}],
#   'rel': 0.341,
#   'typ': 'BIF'},
#  {'dir': 16,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 50,
#   'mx': 169,
#   'my': 221,
#   'neighbours': [{'dir': 17, 'mx': 183, 'my': 177, 'rc': 1},
#    {'dir': 0, 'mx': 189, 'my': 179, 'rc': 2},
#    {'dir': 15, 'mx': 197, 'my': 211, 'rc': 2},
#    {'dir': 29, 'mx': 186, 'my': 255, 'rc': 1},
#    {'dir': 2, 'mx': 170, 'my': 245, 'rc': 0}],
#   'rel': 0.34,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 51,
#   'mx': 170,
#   'my': 245,
#   'neighbours': [{'dir': 0, 'mx': 189, 'my': 179, 'rc': 2},
#    {'dir': 15, 'mx': 197, 'my': 211, 'rc': 2},
#    {'dir': 28, 'mx': 215, 'my': 273, 'rc': 2},
#    {'dir': 29, 'mx': 186, 'my': 255, 'rc': 0},
#    {'dir': 27, 'mx': 204, 'my': 298, 'rc': 1}],
#   'rel': 0.336,
#   'typ': 'RIG'},
#  {'dir': 6,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 54,
#   'mx': 177,
#   'my': 31,
#   'neighbours': [{'dir': 8, 'mx': 229, 'my': 24, 'rc': 2},
#    {'dir': 24, 'mx': 221, 'my': 29, 'rc': 0},
#    {'dir': 9, 'mx': 243, 'my': 38, 'rc': 2},
#    {'dir': 25, 'mx': 241, 'my': 46, 'rc': 2},
#    {'dir': 21, 'mx': 207, 'my': 101, 'rc': 7}],
#   'rel': 0.334,
#   'typ': 'BIF'},
#  {'dir': 24,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 75,
#   'mx': 221,
#   'my': 29,
#   'neighbours': [{'dir': 8, 'mx': 229, 'my': 24, 'rc': 0},
#    {'dir': 25, 'mx': 277, 'my': 36, 'rc': 1},
#    {'dir': 9, 'mx': 243, 'my': 38, 'rc': 0},
#    {'dir': 25, 'mx': 241, 'my': 46, 'rc': 1},
#    {'dir': 26, 'mx': 262, 'my': 88, 'rc': 5}],
#   'rel': 0.331,
#   'typ': 'BIF'},
#  {'dir': 17,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 27,
#   'mx': 121,
#   'my': 277,
#   'neighbours': [{'dir': 4, 'mx': 167, 'my': 290, 'rc': 4},
#    {'dir': 4, 'mx': 154, 'my': 302, 'rc': 2},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 3},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 3},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 0}],
#   'rel': 0.329,
#   'typ': 'RIG'},
#  {'dir': 25,
#   'fn': 4,
#   'ftyp': 'DIS',
#   'id': 80,
#   'mx': 241,
#   'my': 46,
#   'neighbours': [{'dir': 9, 'mx': 243, 'my': 38, 'rc': 0},
#    {'dir': 25, 'mx': 277, 'my': 36, 'rc': 2},
#    {'dir': 10, 'mx': 276, 'my': 78, 'rc': 2},
#    {'dir': 26, 'mx': 262, 'my': 88, 'rc': 4},
#    {'dir': 10, 'mx': 261, 'my': 99, 'rc': 5}],
#   'rel': 0.329,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 36,
#   'mx': 135,
#   'my': 159,
#   'neighbours': [{'dir': 2, 'mx': 158, 'my': 148, 'rc': 2},
#    {'dir': 18, 'mx': 164, 'my': 149, 'rc': 2},
#    {'dir': 18, 'mx': 191, 'my': 144, 'rc': 5},
#    {'dir': 0, 'mx': 189, 'my': 179, 'rc': 6},
#    {'dir': 17, 'mx': 183, 'my': 177, 'rc': 5}],
#   'rel': 0.327,
#   'typ': 'BIF'},
#  {'dir': 15,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 64,
#   'mx': 197,
#   'my': 211,
#   'neighbours': [{'dir': 3, 'mx': 209, 'my': 140, 'rc': 1},
#    {'dir': 22, 'mx': 232, 'my': 143, 'rc': 4},
#    {'dir': 13, 'mx': 249, 'my': 168, 'rc': 5},
#    {'dir': 13, 'mx': 261, 'my': 244, 'rc': 3},
#    {'dir': 28, 'mx': 215, 'my': 273, 'rc': 1}],
#   'rel': 0.323,
#   'typ': 'RIG'},
#  {'dir': 3,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 34,
#   'mx': 132,
#   'my': 71,
#   'neighbours': [{'dir': 23, 'mx': 177, 'my': 15, 'rc': 1},
#    {'dir': 6, 'mx': 177, 'my': 31, 'rc': 0},
#    {'dir': 4, 'mx': 152, 'my': 77, 'rc': 1},
#    {'dir': 21, 'mx': 207, 'my': 101, 'rc': 7},
#    {'dir': 2, 'mx': 158, 'my': 148, 'rc': 6}],
#   'rel': 0.321,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 125,
#   'mx': 465,
#   'my': 110,
#   'neighbours': [{'dir': 26, 'mx': 492, 'my': 472, 'rc': 21},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 22},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 21}],
#   'rel': 0.314,
#   'typ': 'BIF'},
#  {'dir': 4,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 43,
#   'mx': 152,
#   'my': 77,
#   'neighbours': [{'dir': 23, 'mx': 177, 'my': 15, 'rc': 4},
#    {'dir': 6, 'mx': 177, 'my': 31, 'rc': 2},
#    {'dir': 21, 'mx': 207, 'my': 101, 'rc': 5},
#    {'dir': 18, 'mx': 164, 'my': 149, 'rc': 5},
#    {'dir': 2, 'mx': 158, 'my': 148, 'rc': 4}],
#   'rel': 0.313,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 124,
#   'mx': 463,
#   'my': 470,
#   'neighbours': [{'dir': 28, 'mx': 465, 'my': 110, 'rc': 22},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 1},
#    {'dir': 26, 'mx': 492, 'my': 472, 'rc': 1},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 0}],
#   'rel': 0.188,
#   'typ': 'RIG'},
#  {'dir': 24,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 104,
#   'mx': 327,
#   'my': 444,
#   'neighbours': [{'dir': 10, 'mx': 378, 'my': 415, 'rc': 3},
#    {'dir': 25, 'mx': 363, 'my': 445, 'rc': 1},
#    {'dir': 9, 'mx': 383, 'my': 452, 'rc': 2},
#    {'dir': 9, 'mx': 340, 'my': 448, 'rc': 1},
#    {'dir': 25, 'mx': 380, 'my': 463, 'rc': 1}],
#   'rel': 0.179,
#   'typ': 'RIG'},
#  {'dir': 9,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 113,
#   'mx': 383,
#   'my': 452,
#   'neighbours': [{'dir': 26, 'mx': 384, 'my': 382, 'rc': 5},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 2},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 3},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 1},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 0}],
#   'rel': 0.172,
#   'typ': 'BIF'},
#  {'dir': 3,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 32,
#   'mx': 129,
#   'my': 420,
#   'neighbours': [{'dir': 0, 'mx': 144, 'my': 374, 'rc': 1},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 0},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 2},
#    {'dir': 3, 'mx': 142, 'my': 415, 'rc': 0},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 1}],
#   'rel': 0.169,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 17,
#   'mx': 99,
#   'my': 123,
#   'neighbours': [{'dir': 3, 'mx': 132, 'my': 71, 'rc': 0},
#    {'dir': 18, 'mx': 115, 'my': 121, 'rc': 0},
#    {'dir': 2, 'mx': 158, 'my': 148, 'rc': 6},
#    {'dir': 18, 'mx': 135, 'my': 159, 'rc': 4},
#    {'dir': 2, 'mx': 108, 'my': 159, 'rc': 1}],
#   'rel': 0.166,
#   'typ': 'BIF'},
#  {'dir': 21,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 31,
#   'mx': 128,
#   'my': 429,
#   'neighbours': [{'dir': 3, 'mx': 129, 'my': 420, 'rc': 0},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 1},
#    {'dir': 3, 'mx': 142, 'my': 415, 'rc': 0},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 1},
#    {'dir': 7, 'mx': 134, 'my': 474, 'rc': 3}],
#   'rel': 0.166,
#   'typ': 'RIG'},
#  {'dir': 7,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 52,
#   'mx': 170,
#   'my': 458,
#   'neighbours': [{'dir': 21, 'mx': 178, 'my': 444, 'rc': 0},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 1},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 1},
#    {'dir': 22, 'mx': 204, 'my': 444, 'rc': 0},
#    {'dir': 6, 'mx': 199, 'my': 453, 'rc': 2}],
#   'rel': 0.165,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 120,
#   'mx': 438,
#   'my': 469,
#   'neighbours': [{'dir': 27, 'mx': 446, 'my': 312, 'rc': 11},
#    {'dir': 10, 'mx': 476, 'my': 464, 'rc': 2},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 0},
#    {'dir': 26, 'mx': 492, 'my': 472, 'rc': 1},
#    {'dir': 26, 'mx': 489, 'my': 476, 'rc': 0}],
#   'rel': 0.165,
#   'typ': 'RIG'},
#  {'dir': 25,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 110,
#   'mx': 380,
#   'my': 463,
#   'neighbours': [{'dir': 26, 'mx': 384, 'my': 382, 'rc': 6},
#    {'dir': 9, 'mx': 383, 'my': 452, 'rc': 1},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 4},
#    {'dir': 26, 'mx': 463, 'my': 470, 'rc': 2},
#    {'dir': 26, 'mx': 438, 'my': 469, 'rc': 1}],
#   'rel': 0.163,
#   'typ': 'RIG'},
#  {'dir': 29,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 57,
#   'mx': 186,
#   'my': 255,
#   'neighbours': [{'dir': 15, 'mx': 197, 'my': 211, 'rc': 2},
#    {'dir': 13, 'mx': 261, 'my': 244, 'rc': 6},
#    {'dir': 28, 'mx': 215, 'my': 273, 'rc': 1},
#    {'dir': 27, 'mx': 204, 'my': 298, 'rc': 1},
#    {'dir': 10, 'mx': 189, 'my': 314, 'rc': 5}],
#   'rel': 0.162,
#   'typ': 'RIG'},
#  {'dir': 13,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 82,
#   'mx': 249,
#   'my': 168,
#   'neighbours': [{'dir': 25, 'mx': 263, 'my': 117, 'rc': 4},
#    {'dir': 13, 'mx': 315, 'my': 183, 'rc': 4},
#    {'dir': 12, 'mx': 264, 'my': 173, 'rc': 1},
#    {'dir': 29, 'mx': 307, 'my': 192, 'rc': 3},
#    {'dir': 28, 'mx': 304, 'my': 211, 'rc': 1}],
#   'rel': 0.162,
#   'typ': 'RIG'},
#  {'dir': 25,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 76,
#   'mx': 224,
#   'my': 372,
#   'neighbours': [{'dir': 26, 'mx': 228, 'my': 327, 'rc': 4},
#    {'dir': 27, 'mx': 255, 'my': 319, 'rc': 5},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 1},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 2},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 0}],
#   'rel': 0.159,
#   'typ': 'RIG'},
#  {'dir': 15,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 42,
#   'mx': 150,
#   'my': 371,
#   'neighbours': [{'dir': 10, 'mx': 166, 'my': 363, 'rc': 2},
#    {'dir': 8, 'mx': 201, 'my': 374, 'rc': 3},
#    {'dir': 22, 'mx': 195, 'my': 389, 'rc': 1},
#    {'dir': 22, 'mx': 189, 'my': 393, 'rc': 2},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 1}],
#   'rel': 0.158,
#   'typ': 'RIG'},
#  {'dir': 23,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 72,
#   'mx': 209,
#   'my': 437,
#   'neighbours': [{'dir': 25, 'mx': 211, 'my': 368, 'rc': 5},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 4},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 5},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 5},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 4}],
#   'rel': 0.158,
#   'typ': 'BIF'},
#  {'dir': 3,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 3,
#   'mx': 27,
#   'my': 50,
#   'neighbours': [{'dir': 4, 'mx': 116, 'my': 27, 'rc': 6},
#    {'dir': 3, 'mx': 70, 'my': 56, 'rc': 3},
#    {'dir': 2, 'mx': 99, 'my': 123, 'rc': 8},
#    {'dir': 18, 'mx': 80, 'my': 122, 'rc': 6},
#    {'dir': 2, 'mx': 39, 'my': 145, 'rc': 3}],
#   'rel': 0.157,
#   'typ': 'RIG'},
#  {'dir': 3,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 41,
#   'mx': 149,
#   'my': 329,
#   'neighbours': [{'dir': 4, 'mx': 154, 'my': 302, 'rc': 1},
#    {'dir': 4, 'mx': 167, 'my': 290, 'rc': 2},
#    {'dir': 10, 'mx': 189, 'my': 314, 'rc': 2},
#    {'dir': 10, 'mx': 166, 'my': 363, 'rc': 2},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 0}],
#   'rel': 0.155,
#   'typ': 'BIF'},
#  {'dir': 6,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 62,
#   'mx': 192,
#   'my': 422,
#   'neighbours': [{'dir': 22, 'mx': 195, 'my': 389, 'rc': 1},
#    {'dir': 8, 'mx': 201, 'my': 374, 'rc': 3},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 1},
#    {'dir': 22, 'mx': 204, 'my': 444, 'rc': 2},
#    {'dir': 6, 'mx': 199, 'my': 453, 'rc': 3}],
#   'rel': 0.155,
#   'typ': 'RIG'},
#  {'dir': 3,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 38,
#   'mx': 142,
#   'my': 415,
#   'neighbours': [{'dir': 0, 'mx': 144, 'my': 374, 'rc': 0},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 0},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 0},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 2},
#    {'dir': 21, 'mx': 178, 'my': 444, 'rc': 2}],
#   'rel': 0.154,
#   'typ': 'BIF'},
#  {'dir': 10,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 48,
#   'mx': 166,
#   'my': 363,
#   'neighbours': [{'dir': 25, 'mx': 206, 'my': 329, 'rc': 2},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 0},
#    {'dir': 8, 'mx': 201, 'my': 374, 'rc': 1},
#    {'dir': 22, 'mx': 195, 'my': 389, 'rc': 1},
#    {'dir': 22, 'mx': 189, 'my': 393, 'rc': 1}],
#   'rel': 0.154,
#   'typ': 'BIF'},
#  {'dir': 7,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 46,
#   'mx': 162,
#   'my': 393,
#   'neighbours': [{'dir': 10, 'mx': 166, 'my': 363, 'rc': 3},
#    {'dir': 8, 'mx': 201, 'my': 374, 'rc': 1},
#    {'dir': 22, 'mx': 195, 'my': 389, 'rc': 0},
#    {'dir': 22, 'mx': 189, 'my': 393, 'rc': 1},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 2}],
#   'rel': 0.153,
#   'typ': 'RIG'},
#  {'dir': 22,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 68,
#   'mx': 204,
#   'my': 444,
#   'neighbours': [{'dir': 25, 'mx': 211, 'my': 368, 'rc': 6},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 5},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 6},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 0},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 4}],
#   'rel': 0.153,
#   'typ': 'BIF'},
#  {'dir': 21,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 55,
#   'mx': 178,
#   'my': 444,
#   'neighbours': [{'dir': 22, 'mx': 189, 'my': 393, 'rc': 3},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 1},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 0},
#    {'dir': 22, 'mx': 204, 'my': 444, 'rc': 1},
#    {'dir': 6, 'mx': 199, 'my': 453, 'rc': 3}],
#   'rel': 0.152,
#   'typ': 'RIG'},
#  {'dir': 22,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 10,
#   'mx': 72,
#   'my': 398,
#   'neighbours': [{'dir': 18, 'mx': 94, 'my': 351, 'rc': 1},
#    {'dir': 20, 'mx': 101, 'my': 381, 'rc': 0},
#    {'dir': 3, 'mx': 129, 'my': 420, 'rc': 3},
#    {'dir': 21, 'mx': 128, 'my': 429, 'rc': 3},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 4}],
#   'rel': 0.151,
#   'typ': 'RIG'},
#  {'dir': 5,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 37,
#   'mx': 140,
#   'my': 446,
#   'neighbours': [{'dir': 3, 'mx': 142, 'my': 415, 'rc': 2},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 3},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 1},
#    {'dir': 21, 'mx': 178, 'my': 444, 'rc': 0},
#    {'dir': 7, 'mx': 170, 'my': 458, 'rc': 2}],
#   'rel': 0.151,
#   'typ': 'RIG'},
#  {'dir': 0,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 39,
#   'mx': 144,
#   'my': 374,
#   'neighbours': [{'dir': 3, 'mx': 149, 'my': 329, 'rc': 1},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 0},
#    {'dir': 10, 'mx': 166, 'my': 363, 'rc': 2},
#    {'dir': 22, 'mx': 189, 'my': 393, 'rc': 3},
#    {'dir': 7, 'mx': 162, 'my': 393, 'rc': 2}],
#   'rel': 0.151,
#   'typ': 'RIG'},
#  {'dir': 28,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 74,
#   'mx': 215,
#   'my': 273,
#   'neighbours': [{'dir': 13, 'mx': 261, 'my': 244, 'rc': 4},
#    {'dir': 28, 'mx': 286, 'my': 290, 'rc': 3},
#    {'dir': 28, 'mx': 255, 'my': 287, 'rc': 1},
#    {'dir': 27, 'mx': 255, 'my': 319, 'rc': 1},
#    {'dir': 26, 'mx': 228, 'my': 327, 'rc': 3}],
#   'rel': 0.151,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 1,
#   'mx': 19,
#   'my': 102,
#   'neighbours': [{'dir': 3, 'mx': 27, 'my': 50, 'rc': 0},
#    {'dir': 3, 'mx': 70, 'my': 56, 'rc': 2},
#    {'dir': 18, 'mx': 80, 'my': 122, 'rc': 5},
#    {'dir': 2, 'mx': 39, 'my': 145, 'rc': 2},
#    {'dir': 2, 'mx': 19, 'my': 175, 'rc': 1}],
#   'rel': 0.15,
#   'typ': 'RIG'},
#  {'dir': 5,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 7,
#   'mx': 49,
#   'my': 347,
#   'neighbours': [{'dir': 18, 'mx': 106, 'my': 316, 'rc': 0},
#    {'dir': 19, 'mx': 104, 'my': 329, 'rc': 1},
#    {'dir': 18, 'mx': 94, 'my': 351, 'rc': 2},
#    {'dir': 20, 'mx': 101, 'my': 381, 'rc': 4},
#    {'dir': 22, 'mx': 72, 'my': 398, 'rc': 3}],
#   'rel': 0.15,
#   'typ': 'RIG'},
#  {'dir': 19,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 19,
#   'mx': 104,
#   'my': 329,
#   'neighbours': [{'dir': 18, 'mx': 106, 'my': 316, 'rc': 0},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 1},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 3},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 3},
#    {'dir': 1, 'mx': 125, 'my': 331, 'rc': 2}],
#   'rel': 0.15,
#   'typ': 'RIG'},
#  {'dir': 19,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 40,
#   'mx': 147,
#   'my': 321,
#   'neighbours': [{'dir': 4, 'mx': 154, 'my': 302, 'rc': 1},
#    {'dir': 4, 'mx': 167, 'my': 290, 'rc': 1},
#    {'dir': 10, 'mx': 189, 'my': 314, 'rc': 2},
#    {'dir': 10, 'mx': 166, 'my': 363, 'rc': 4},
#    {'dir': 3, 'mx': 149, 'my': 329, 'rc': 0}],
#   'rel': 0.15,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 21,
#   'mx': 106,
#   'my': 316,
#   'neighbours': [{'dir': 17, 'mx': 107, 'my': 282, 'rc': 0},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 1},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 3},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 3},
#    {'dir': 1, 'mx': 125, 'my': 331, 'rc': 2}],
#   'rel': 0.149,
#   'typ': 'RIG'},
#  {'dir': 7,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 35,
#   'mx': 134,
#   'my': 474,
#   'neighbours': [{'dir': 3, 'mx': 142, 'my': 415, 'rc': 3},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 2},
#    {'dir': 21, 'mx': 178, 'my': 444, 'rc': 1},
#    {'dir': 7, 'mx': 170, 'my': 458, 'rc': 1},
#    {'dir': 6, 'mx': 199, 'my': 453, 'rc': 2}],
#   'rel': 0.149,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 73,
#   'mx': 211,
#   'my': 368,
#   'neighbours': [{'dir': 26, 'mx': 228, 'my': 327, 'rc': 4},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 1},
#    {'dir': 25, 'mx': 274, 'my': 356, 'rc': 1},
#    {'dir': 25, 'mx': 264, 'my': 373, 'rc': 0},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 0}],
#   'rel': 0.149,
#   'typ': 'BIF'},
#  {'dir': 4,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 49,
#   'mx': 167,
#   'my': 290,
#   'neighbours': [{'dir': 2, 'mx': 170, 'my': 245, 'rc': 1},
#    {'dir': 29, 'mx': 186, 'my': 255, 'rc': 1},
#    {'dir': 28, 'mx': 215, 'my': 273, 'rc': 3},
#    {'dir': 27, 'mx': 204, 'my': 298, 'rc': 0},
#    {'dir': 10, 'mx': 189, 'my': 314, 'rc': 2}],
#   'rel': 0.148,
#   'typ': 'RIG'},
#  {'dir': 17,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 20,
#   'mx': 106,
#   'my': 264,
#   'neighbours': [{'dir': 2, 'mx': 111, 'my': 238, 'rc': 0},
#    {'dir': 17, 'mx': 121, 'my': 277, 'rc': 0},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 0},
#    {'dir': 17, 'mx': 107, 'my': 282, 'rc': 0},
#    {'dir': 18, 'mx': 106, 'my': 316, 'rc': 1}],
#   'rel': 0.147,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 33,
#   'mx': 131,
#   'my': 330,
#   'neighbours': [{'dir': 4, 'mx': 154, 'my': 302, 'rc': 1},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 0},
#    {'dir': 3, 'mx': 149, 'my': 329, 'rc': 1},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 2},
#    {'dir': 0, 'mx': 144, 'my': 374, 'rc': 0}],
#   'rel': 0.147,
#   'typ': 'BIF'},
#  {'dir': 22,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 60,
#   'mx': 189,
#   'my': 393,
#   'neighbours': [{'dir': 8, 'mx': 201, 'my': 374, 'rc': 2},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 2},
#    {'dir': 22, 'mx': 195, 'my': 389, 'rc': 0},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 1},
#    {'dir': 6, 'mx': 192, 'my': 422, 'rc': 1}],
#   'rel': 0.147,
#   'typ': 'BIF'},
#  {'dir': 5,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 29,
#   'mx': 124,
#   'my': 447,
#   'neighbours': [{'dir': 3, 'mx': 129, 'my': 420, 'rc': 2},
#    {'dir': 21, 'mx': 128, 'my': 429, 'rc': 0},
#    {'dir': 3, 'mx': 142, 'my': 415, 'rc': 1},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 0},
#    {'dir': 7, 'mx': 134, 'my': 474, 'rc': 2}],
#   'rel': 0.146,
#   'typ': 'RIG'},
#  {'dir': 18,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 15,
#   'mx': 95,
#   'my': 299,
#   'neighbours': [{'dir': 17, 'mx': 107, 'my': 282, 'rc': 0},
#    {'dir': 17, 'mx': 121, 'my': 277, 'rc': 1},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 1},
#    {'dir': 18, 'mx': 106, 'my': 316, 'rc': 0},
#    {'dir': 19, 'mx': 104, 'my': 329, 'rc': 1}],
#   'rel': 0.145,
#   'typ': 'BIF'},
#  {'dir': 23,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 16,
#   'mx': 95,
#   'my': 457,
#   'neighbours': [{'dir': 3, 'mx': 129, 'my': 420, 'rc': 2},
#    {'dir': 21, 'mx': 128, 'my': 429, 'rc': 2},
#    {'dir': 5, 'mx': 124, 'my': 447, 'rc': 0},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 0},
#    {'dir': 7, 'mx': 134, 'my': 474, 'rc': 2}],
#   'rel': 0.145,
#   'typ': 'RIG'},
#  {'dir': 20,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 18,
#   'mx': 101,
#   'my': 381,
#   'neighbours': [{'dir': 19, 'mx': 104, 'my': 329, 'rc': 0},
#    {'dir': 15, 'mx': 150, 'my': 371, 'rc': 3},
#    {'dir': 0, 'mx': 144, 'my': 374, 'rc': 3},
#    {'dir': 3, 'mx': 142, 'my': 415, 'rc': 4},
#    {'dir': 3, 'mx': 129, 'my': 420, 'rc': 3}],
#   'rel': 0.144,
#   'typ': 'RIG'},
#  {'dir': 17,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 22,
#   'mx': 107,
#   'my': 282,
#   'neighbours': [{'dir': 2, 'mx': 111, 'my': 238, 'rc': 0},
#    {'dir': 17, 'mx': 121, 'my': 277, 'rc': 0},
#    {'dir': 4, 'mx': 154, 'my': 302, 'rc': 3},
#    {'dir': 2, 'mx': 123, 'my': 316, 'rc': 0},
#    {'dir': 1, 'mx': 125, 'my': 331, 'rc': 2}],
#   'rel': 0.144,
#   'typ': 'BIF'},
#  {'dir': 1,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 30,
#   'mx': 125,
#   'my': 331,
#   'neighbours': [{'dir': 4, 'mx': 154, 'my': 302, 'rc': 1},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 0},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 0},
#    {'dir': 3, 'mx': 149, 'my': 329, 'rc': 2},
#    {'dir': 0, 'mx': 144, 'my': 374, 'rc': 1}],
#   'rel': 0.144,
#   'typ': 'BIF'},
#  {'dir': 25,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 69,
#   'mx': 206,
#   'my': 329,
#   'neighbours': [{'dir': 27, 'mx': 255, 'my': 319, 'rc': 3},
#    {'dir': 26, 'mx': 228, 'my': 327, 'rc': 1},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 1},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 2},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 3}],
#   'rel': 0.143,
#   'typ': 'BIF'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 28,
#   'mx': 123,
#   'my': 316,
#   'neighbours': [{'dir': 4, 'mx': 154, 'my': 302, 'rc': 1},
#    {'dir': 19, 'mx': 147, 'my': 321, 'rc': 2},
#    {'dir': 3, 'mx': 149, 'my': 329, 'rc': 3},
#    {'dir': 18, 'mx': 131, 'my': 330, 'rc': 2},
#    {'dir': 1, 'mx': 125, 'my': 331, 'rc': 1}],
#   'rel': 0.142,
#   'typ': 'RIG'},
#  {'dir': 22,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 63,
#   'mx': 195,
#   'my': 389,
#   'neighbours': [{'dir': 8, 'mx': 201, 'my': 374, 'rc': 1},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 2},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 1},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 4},
#    {'dir': 22, 'mx': 204, 'my': 444, 'rc': 4}],
#   'rel': 0.141,
#   'typ': 'RIG'},
#  {'dir': 7,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 11,
#   'mx': 72,
#   'my': 463,
#   'neighbours': [{'dir': 21, 'mx': 128, 'my': 429, 'rc': 1},
#    {'dir': 5, 'mx': 124, 'my': 447, 'rc': 1},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 0},
#    {'dir': 8, 'mx': 85, 'my': 464, 'rc': 0},
#    {'dir': 7, 'mx': 134, 'my': 474, 'rc': 1}],
#   'rel': 0.138,
#   'typ': 'RIG'},
#  {'dir': 8,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 66,
#   'mx': 201,
#   'my': 374,
#   'neighbours': [{'dir': 25, 'mx': 206, 'my': 329, 'rc': 4},
#    {'dir': 26, 'mx': 228, 'my': 327, 'rc': 5},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 0},
#    {'dir': 9, 'mx': 253, 'my': 359, 'rc': 1},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 0}],
#   'rel': 0.138,
#   'typ': 'BIF'},
#  {'dir': 8,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 13,
#   'mx': 85,
#   'my': 464,
#   'neighbours': [{'dir': 21, 'mx': 128, 'my': 429, 'rc': 1},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 0},
#    {'dir': 5, 'mx': 124, 'my': 447, 'rc': 0},
#    {'dir': 5, 'mx': 140, 'my': 446, 'rc': 1},
#    {'dir': 7, 'mx': 134, 'my': 474, 'rc': 1}],
#   'rel': 0.127,
#   'typ': 'RIG'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 128,
#   'mx': 492,
#   'my': 472,
#   'neighbours': [],
#   'rel': 0.078,
#   'typ': 'BIF'},
#  {'dir': 9,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 105,
#   'mx': 340,
#   'my': 448,
#   'neighbours': [{'dir': 10, 'mx': 378, 'my': 415, 'rc': 3},
#    {'dir': 26, 'mx': 414, 'my': 427, 'rc': 3},
#    {'dir': 25, 'mx': 363, 'my': 445, 'rc': 0},
#    {'dir': 9, 'mx': 383, 'my': 452, 'rc': 1},
#    {'dir': 25, 'mx': 380, 'my': 463, 'rc': 0}],
#   'rel': 0.072,
#   'typ': 'BIF'},
#  {'dir': 26,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 127,
#   'mx': 489,
#   'my': 476,
#   'neighbours': [{'dir': 26, 'mx': 492, 'my': 472, 'rc': 0}],
#   'rel': 0.072,
#   'typ': 'BIF'},
#  {'dir': 23,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 53,
#   'mx': 177,
#   'my': 15,
#   'neighbours': [{'dir': 8, 'mx': 229, 'my': 24, 'rc': 2},
#    {'dir': 24, 'mx': 221, 'my': 29, 'rc': 2},
#    {'dir': 9, 'mx': 243, 'my': 38, 'rc': 3},
#    {'dir': 25, 'mx': 241, 'my': 46, 'rc': 4},
#    {'dir': 6, 'mx': 177, 'my': 31, 'rc': 1}],
#   'rel': 0.07,
#   'typ': 'BIF'},
#  {'dir': 6,
#   'fn': 3,
#   'ftyp': 'APP',
#   'id': 65,
#   'mx': 199,
#   'my': 453,
#   'neighbours': [{'dir': 8, 'mx': 201, 'my': 374, 'rc': 6},
#    {'dir': 25, 'mx': 211, 'my': 368, 'rc': 7},
#    {'dir': 25, 'mx': 224, 'my': 372, 'rc': 6},
#    {'dir': 22, 'mx': 204, 'my': 444, 'rc': 0},
#    {'dir': 23, 'mx': 209, 'my': 437, 'rc': 0}],
#   'rel': 0.069,
#   'typ': 'BIF'},
#  {'dir': 18,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 0,
#   'mx': 12,
#   'my': 238,
#   'neighbours': [{'dir': 2, 'mx': 19, 'my': 175, 'rc': 1},
#    {'dir': 2, 'mx': 39, 'my': 145, 'rc': 1},
#    {'dir': 2, 'mx': 111, 'my': 238, 'rc': 7},
#    {'dir': 17, 'mx': 106, 'my': 264, 'rc': 7},
#    {'dir': 18, 'mx': 95, 'my': 299, 'rc': 8}],
#   'rel': 0.064,
#   'typ': 'RIG'},
#  {'dir': 2,
#   'fn': 1,
#   'ftyp': 'DIS',
#   'id': 2,
#   'mx': 19,
#   'my': 175,
#   'neighbours': [{'dir': 2, 'mx': 39, 'my': 145, 'rc': 0},
#    {'dir': 18, 'mx': 80, 'my': 122, 'rc': 2},
#    {'dir': 2, 'mx': 99, 'my': 123, 'rc': 5},
#    {'dir': 18, 'mx': 115, 'my': 121, 'rc': 5},
#    {'dir': 2, 'mx': 108, 'my': 159, 'rc': 6}],
#   'rel': 0.063,
#   'typ': 'RIG'},
#  {'dir': 22,
#   'fn': 2,
#   'ftyp': 'DIS',
#   'id': 5,
#   'mx': 40,
#   'my': 460,
#   'neighbours': [{'dir': 6, 'mx': 60, 'my': 431, 'rc': 0},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 1},
#    {'dir': 8, 'mx': 85, 'my': 464, 'rc': 2},
#    {'dir': 7, 'mx': 72, 'my': 463, 'rc': 1},
#    {'dir': 7, 'mx': 44, 'my': 470, 'rc': 0}],
#   'rel': 0.063,
#   'typ': 'BIF'},
#  {'dir': 7,
#   'fn': 0,
#   'ftyp': 'APP',
#   'id': 6,
#   'mx': 44,
#   'my': 470,
#   'neighbours': [{'dir': 22, 'mx': 72, 'my': 398, 'rc': 2},
#    {'dir': 6, 'mx': 60, 'my': 431, 'rc': 1},
#    {'dir': 23, 'mx': 95, 'my': 457, 'rc': 1},
#    {'dir': 7, 'mx': 72, 'my': 463, 'rc': 0},
#    {'dir': 8, 'mx': 85, 'my': 464, 'rc': 0}],
#   'rel': 0.062,
#   'typ': 'RIG'}]

# %%
def minutiaIntoBytes(minutia, norm=500):
    """
    Data format (bytes):
        0:    mx
        1:    my
        2:    dir
        3-6:  neigh1
        7-10: neigh2
        11-14:  neigh3
        15-18:  neigh4
        19-22:  neigh5
        neigh:
            0: mx
            1: my
            2: dir
            3: rc
    """
    base = [
        int(minutia["mx"] * 256 / norm) ,
        int(minutia["my"] * 256 / norm) ,
        minutia["dir"],
    ]
    for neigh in minutia["neighbours"]:
        base += [
            int(neigh["mx"] * 256 / norm) ,
            int(neigh["my"] * 256 / norm) ,
            neigh["dir"],
            neigh["rc"],
        ]
    for _ in range(5-len(minutia["neighbours"])):
        base += [255]*4
    return (base)

# %%
def fingerIntoBytes(finger, norm=500):
    finger = sorted(finger, key=lambda f: -f["rel"])
    fold = lambda x: x[0]+fold(x[1:]) if x else []
    return fold ([minutiaIntoBytes(minutia,norm) for minutia,_ in zip(finger, range(10))])

# %%
def bytesIntoFingers(finger, norm=500):
    """
    Data format (bytes):
        0:    mx
        1:    my
        2:    dir
        3-6:  neigh1
        7-10: neigh2
        11-14:  neigh3
        15-18:  neigh4
        19-22:  neigh5
        neigh:
            0: mx
            1: my
            2: dir
            3: rc
    """
    res = {}
    res['mx'] = finger[0] * norm / 256
    res['my'] = finger[1] * norm / 256
    res['dir']= finger[2] * norm / 256

# %%
def writeFingerToFile(filename, finger):
    res = fingerIntoBytes(finger)
    print(len(res), [x-128 for x in res])
    res = bytearray(res)
    f = open(filename, 'wb')
    f.write(res)
    f.close()

# %%
writeFingerToFile("out.dat", testFinger)
# Out:
# 230 [62, -93, -100, 68, -118, -118, -125, 80, -58, -115, -127, 75, -56, -99, -127, 71, -64, -115, -127, 67, -54, -98, -126, 97, 75, -104, 110, 5, -98, -119, 106, 33, -103, -122, 125, -58, -99, -112, 121, 28, -102, -121, 108, 73, -120, -127, 108, 73, -120, 112, -73, -115, -114, 110, 5, -98, -120, 125, -58, -99, -113, 121, 28, -102, -122, 127, 127, 127, 127, 106, 33, -103, 112, -73, -115, -118, 110, 5, -98, -125, 125, -58, -99, -118, 121, 28, -102, -127, 108, 73, -120, -122, 58, 84, -120, 60, 58, -120, -124, 68, 53, -104, -123, 75, 71, -120, -126, 82, 94, -120, -127, 83, 103, -104, -126, 75, 71, -120, 106, 33, -103, -123, 108, 73, -120, -127, 97, 75, -104, -128, 82, 94, -120, -125, 83, 103, -104, -124, -42, 60, -119, -28, 40, -103, -125, -33, 56, -103, -128, -30, 74, -104, -127, -33, 101, -104, -123, -36, 95, -104, -123, 60, 58, -120, 63, 13, -122, -121, 68, 53, -104, -127, 97, 75, -104, -126, 75, 71, -120, -126, 82, 94, -120, -123, 52, 52, -104, 55, 33, -120, -125, 68, 53, -104, -128, 60, 58, -120, -127, 75, 71, -120, -125, 58, 84, -120, -124, -47, 53, -104, -47, 40, -119, -126, -28, 40, -103, -126, -33, 56, -103, -128, -30, 74, -104, -126, -42, 60, -119, -127]
